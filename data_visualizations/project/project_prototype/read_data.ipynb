# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
races_files=['Afrikan_american','American_Indian_Alaska_Native','Asian_Pacific_Islander','white']

# %%
44.0/273831
# Out:
# 0.00016068304903389316

# %%
def get_df(i):
    df=pd.io.parsers.read_csv('raw_Data/%s.txt'%(races_files[i]), sep=r"\s+",quotechar='"',skiprows=[1])
    df=df[~np.all(df.ix[:,1:].isnull(),axis=1)]
    cols=[elt for elt in df.columns if elt not in ['Rate']]
    df=df[cols]
    df=df.rename(columns={'Crude':'Rate'})

    cols=[elt for elt in df.columns if elt not in ['Cancer Sites Code','Age Group','Sex Code','Race Code','Year Code']]
    df=df[cols]
    return df

# %%
pieces = [get_df(i) for i in range(len(races_files))]
concatenated = pd.concat(pieces)
concatenated.to_csv('all_races.csv')
concatenated.shape
# Out:
# (20607, 9)

# %%
concatenated
# Out:
#                        Leading Cancer Sites Leading Cancer Sites Code  \
# 0                        All Sites Combined                        00
# 1                        All Sites Combined                        00
# 2                        All Sites Combined                        00
# 3                        All Sites Combined                        00
# 4                        All Sites Combined                        00
# 5                        All Sites Combined                        00
# 6                        All Sites Combined                        00
# 7                        All Sites Combined                        00
# 8                        All Sites Combined                        00
# 9                        All Sites Combined                        00
# 10                       All Sites Combined                        00
# 11                       All Sites Combined                        00
# 12                       All Sites Combined                        00
# 13                       All Sites Combined                        00
# 14                       All Sites Combined                        00
# 15                       All Sites Combined                        00
# 16                       All Sites Combined                        00
# 17                       All Sites Combined                        00
# 18                       All Sites Combined                        00
# 19                       All Sites Combined                        00
# 20                       All Sites Combined                        00
# 21                       All Sites Combined                        00
# 22                       All Sites Combined                        00
# 23                       All Sites Combined                        00
# 24                       All Sites Combined                        00
# 25                       All Sites Combined                        00
# 26                       All Sites Combined                        00
# 27                       All Sites Combined                        00
# 28                       All Sites Combined                        00
# 29                       All Sites Combined                        00
# ...                                     ...                       ...
# 7932  Urinary Bladder, invasive and in situ                     29010
# 7933  Urinary Bladder, invasive and in situ                     29010
# 7934  Urinary Bladder, invasive and in situ                     29010
# 7935  Urinary Bladder, invasive and in situ                     29010
# 7936  Urinary Bladder, invasive and in situ                     29010
# 7937  Urinary Bladder, invasive and in situ                     29010
# 7938  Urinary Bladder, invasive and in situ                     29010
# 7939  Urinary Bladder, invasive and in situ                     29010
# 7940  Urinary Bladder, invasive and in situ                     29010
# 7941  Urinary Bladder, invasive and in situ                     29010
# 7942  Urinary Bladder, invasive and in situ                     29010
# 7943  Urinary Bladder, invasive and in situ                     29010
# 7944  Urinary Bladder, invasive and in situ                     29010
# 7945  Urinary Bladder, invasive and in situ                     29010
# 7946  Urinary Bladder, invasive and in situ                     29010
# 7947  Urinary Bladder, invasive and in situ                     29010
# 7948  Urinary Bladder, invasive and in situ                     29010
# 7949  Urinary Bladder, invasive and in situ                     29010
# 7950  Urinary Bladder, invasive and in situ                     29010
# 7951  Urinary Bladder, invasive and in situ                     29010
# 7952  Urinary Bladder, invasive and in situ                     29010
# 7953  Urinary Bladder, invasive and in situ                     29010
# 7954  Urinary Bladder, invasive and in situ                     29010
# 7955  Urinary Bladder, invasive and in situ                     29010
# 9         337020   16.6
# 10        330117   21.5
# 11        332106   16.3
# 12        264176   14.8
# 13        283157   17.7
# 14        282276   23.7
# 15        283316   18.7
# 16        307077   15.0
# 17        320836   20.6
# 18        327935   19.2
# 19        337086   21.7
# 20        353833   19.8
# 21        353526   24.0
# 22        346752   19.3
# 23        341854   16.4
# 24        345463   15.3
# 25       1054621   13.5
# 26       1095114   13.8
# 27       1050054   13.8
# 28       1092581   13.4
# 29       1199175   14.4
# ...          ...    ...
# 7932     2030746  346.4
# 7933     2045977  347.1
# 7934     2071102  333.2
# 7935     2078071  327.9
# 7936     2472814   79.3
# 7937     2572012   77.5
# 7938     2581848   80.0
# 7939     2626641   83.0
# 7940     2780061   80.8
# 7941     2864855   82.0
# 7942     2932403   82.7
# 7943     3019641   77.4
# 7944     3103899   80.8
# 7945     3174934   80.4
# 7946     3256693   78.5
# 7947     3337248   75.8
# 7948     3393214   76.8
# 7949     1000242  362.7
# 7950     1054243  356.9
# 7951     1073371  359.7
# 7952     1110879  370.9
# 7953     1197092  363.0
# 7954     1254392  369.7
# 7955     1311223  377.7
# 7956     1379750  378.3
# 7957     1446344  379.9
# 7958     1507160  389.7
# 7959     1570283  386.7
# 7960     1634369  374.9
# 7961     1688433  368.2
#
# [20607 rows x 9 columns]

# %%
df_other=pd.io.parsers.read_csv('raw_Data/%s.txt'%('other'), sep=r"\s+",quotechar='"',skiprows=[1])
df_other=df_other[~np.all(df_other.ix[:,1:].isnull(),axis=1)]

# %%
df_other=df_other[['Age Group','Sex','Year','Year Code']]
df_other=df_other.rename(columns={'Year Code':'Count'})

# %%
df_other.to_csv('other_unknown.csv')

# %%
concatenated[:2]
# Out:
#   Leading Cancer Sites Leading Cancer Sites Code Age Group Code     Sex  \
# 0   All Sites Combined                        00              1  Female
# 1   All Sites Combined                        00              1  Female
#
#                         Race  Year  Count  Population  Rate
# 0  Black or African American  2000     44      273831  16.1
# 1  Black or African American  2001     48      273501  17.6

# %%
48.0/273501
# Out:
# 0.00017550210054076586

# %%
df_1=concatenated.groupby('Leading Cancer Sites').apply(lambda g: int(np.sum(g['Count'])))
df_1=pd.DataFrame(df_1).reset_index()
df_1.rename(columns={'Leading Cancer Sites': 'category', 0:'measure'}, inplace=True)
df_1=df_1[1:]
df_1.to_csv('first_bar_project.csv')
df_1.T.to_json('df_1_project.json')

# %%
df_2=concatenated.groupby(['Leading Cancer Sites','Race','Year'])\
.apply(lambda g: np.sum(g['Rate']*g['Population'])*1.0/np.sum(g['Population'])   )

df_2=pd.DataFrame(df_2)
df_2.reset_index(inplace=True)
df_2.rename(columns={'Leading Cancer Sites': 'group', 'Year':'category',0:'measure'}, inplace=True)
df_2.loc[df_2['group']=='All Sites Combined','group']='All'
df_2.T.to_json('df_2_project.json')

# %%
plt.plot(df['category'],df['measure'])
plt.show()

# %%
df=df_2[df_2.Race=='Black or African American']

# %%
df=df[df.group=='Breast']

# %%
df_2['Race'].unique()
# Out:
# array(['American Indian or Alaska Native', 'Asian or Pacific Islander',
#        'Black or African American', 'White'], dtype=object)
